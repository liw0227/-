cad919862b2ee351a4164264d775a214084c26; token="MzFfR0tHWVJqZVRhdHI5WkR4TWRIemZtbnBvMUxTZ1IwMVgyQzJyaHhjV1A4VXBQWDJjMGJJM3ljbW04eEZkczlWME5mWTdCU2ptbWZaTVNmR1JrVVpiancwUS1xTVJmZ2JBdUhhY3BnMlVyd2M=|1584976799|4f7391400ba9c5a69bb098a1a5a7c91e7442e0e2"; client_id="bzNwMi1qdHMxbUpUREVuSnVXNUt5R2hIa25yZw==|1584976799|ffa961247094078c7851062c00c54791e11b1fe0"; capsion_ticket="2|1:0|10:1584976887|14:capsion_ticket|44:ZDZjYWU2NzZjNzdkNGM2NWI2NjE5YjdjNTEzYTVmYjE=|be468e69af70f173cbc54ef61b7f3af6584ff95d381cad8b5bfcc0adca189eb7"; z_c0="2|1:0|10:1584977271|4:z_c0|92:Mi4xYUVnVEdnQUFBQUFBQUp3Uk0xanZFQ2NBQUFDRUFsVk5kMktnWGdBWHhzbXM5N1hEVjA4aEl5ZlpSVHdnMHE0S2h3|226099bc30f790f44510656d82614dd8fdd9850d068bd9a360b65eda61ae0314"; tst=r; Hm_lpvt_98beee57fd2ef70ccdd5ca52b9740c49=1584980459; KLBRSID=9d75f80756f65c61b0a50d80b4ca9b13|1584980459|1584976482','user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.132 Safari/537.36'}
r = requests.get(url, headers=headers)
r_json = r.json()
items = r_json['data']#时间线列表
print(r_json)
# Out:
# {'data': [{'id': '6_1585067634.295', 'type': 'feed', 'offset': 6, 'verb': 'COMMON_CARD', 'created_time': 1585067634, 'updated_time': 1585067634, 'target': {'id': '1224976467278356480', 'type': 'zvideo', 'title': '蝙蝠示范为何男生小便后不用擦', 'content': '因为，男生有全自动处理方式', 'description': '因为，男生有全自动处理方式', 'member_id': 2480204, 'vote_count': 3246, 'comment_count': 680, 'author': {'id': 'a8c5d61e0811af46240c87d4f875a9da', 'type': 'people', 'url': 'https://api.zhihu.com/people/a8c5d61e0811af46240c87d4f875a9da', 'user_type': 'people', 'url_token': 'dushanbe', 'name': '杜尚别', 'headline': '公众号『遇见杜尚别（全世界最不会讲故事的人）』', 'avatar_url': 'https://pic2.zhimg.com/50/v2-fe58249116fc306ac16587670156a532_m.jpg', 'is_org': False, 'gender': 1, 'badge': [], 'followers_count': 6747, 'is_following': False, 'is_followed': False}, 'thumbnail_extra_info': {'video_id': '1224976461339156480', 'type': 'video', 'url': 'https://pic3.zhimg.com/v2-9f7737e33fe36c75fdf3c845df1481ae.jpg', 'height': 352, 'width': 640, 'duration': 16, 'play
# ...

# %%
items = r_json['data']
for item in items:
    target = item['target']
    target_type = target['type']
    print(target_type)
# Out:
# zvideo
# answer
# answer
# answer
# answer
# answer

# %%
import requests
import csv
import time
for i in range(0, 100, 6):
    url = 'https://www.zhihu.com/api/v3/feed/topstory/recommend?session_token=96fdb2dbcfa86ff0fce8c4bafe91634b&desktop' \
          f'=true&page_number=2&limit=6&action=down&after_id={i}&ad_interval=-1 '
    headers = {'cookie': '_zap=6eee2fad-004b-4562-b831-3c696d166715; '
                         'd_c0="AACcETNY7xCPTviLSXi3AiBeuz0z7tl-ekk=|1583720046"; _ga=GA1.2.1915017077.1583720047; '
                         '_xsrf=4f58f44c-76d7-4672-979b-23337f5828ab; '
                         'Hm_lvt_98beee57fd2ef70ccdd5ca52b9740c49=1584035755, '
                         '1584038771,1584541628,1584976483; _gid=GA1.2.1517727902.1584976483; l_n_c=1; '
                         'r_cap_id="NDVkNzI1YmJiNGVhNGM3ZGJmMzIyM2JlMDkzYWZlODA=|1584976492'
                         '|d0b0b7bcf2243f22c2d45a9f07ce3bf7998360ca"; '
                         'cap_id="YTJlZWM2NTg2M2Y5NDdhOTk5Y2ZlZDkyNTJjNmZhYTc=|1584976492'
                         '|3fa94df715fa587397498fbb70093de73dfd5496"; '
                         'l_cap_id="NjczN2EyNmE2ZWU3NGEyYjhiMDhlNjgwOTM3ZjY3NDY=|1584976492'
                         '|c93ed242f4624d2b04887727024c0ff035398990"; n_c=1; '
                         'auth_type=d2VjaGF0|1584976799|21cad919862b2ee351a4164264d775a214084c26; '
                         'token'
                         '="MzFfR0tHWVJqZVRhdHI5WkR4TWRIemZtbnBvMUxTZ1IwMVgyQzJyaHhjV1A4VXBQWDJjMGJJM3ljbW04eEZkczlWME5mWTdCU2ptbWZaTVNmR1JrVVpiancwUS1xTVJmZ2JBdUhhY3BnMlVyd2M=|1584976799|4f7391400ba9c5a69bb098a1a5a7c91e7442e0e2"; client_id="bzNwMi1qdHMxbUpUREVuSnVXNUt5R2hIa25yZw==|1584976799|ffa961247094078c7851062c00c54791e11b1fe0"; capsion_ticket="2|1:0|10:1584976887|14:capsion_ticket|44:ZDZjYWU2NzZjNzdkNGM2NWI2NjE5YjdjNTEzYTVmYjE=|be468e69af70f173cbc54ef61b7f3af6584ff95d381cad8b5bfcc0adca189eb7"; z_c0="2|1:0|10:1584977271|4:z_c0|92:Mi4xYUVnVEdnQUFBQUFBQUp3Uk0xanZFQ2NBQUFDRUFsVk5kMktnWGdBWHhzbXM5N1hEVjA4aEl5ZlpSVHdnMHE0S2h3|226099bc30f790f44510656d82614dd8fdd9850d068bd9a360b65eda61ae0314"; tst=r; Hm_lpvt_98beee57fd2ef70ccdd5ca52b9740c49=1584980459; KLBRSID=9d75f80756f65c61b0a50d80b4ca9b13|1584980459|1584976482',
               'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) '
                             'Chrome/80.0.3987.132 Safari/537.36'}
    r = requests.get(url, headers=headers)
    r_json = r.json()
    items = r_json['data']

    with open('zhihu.csv', 'a', encoding='utf-8') as f:  # 打开并追加写入
        f_csv = csv.writer(f)

        for item in items:
            target = item['target']
            target_type = target['type']

            if target_type == 'answer':
                question = target['question']

                line = [
                    'answer', item.get('id'), item.get('action_text'),  # 类型，总 id，关键词
                    target.get('id'), target.get('voteup_count'), target.get('comment_count'),  # 回答 id，回答点赞数，回答评论数
                    target.get('thanks_count'), target.get('visited_count'), target.get('created_time'),
                    # 回答感谢数，回答观看数，回答创建时间
                    question.get('id'), question.get('title'), question.get('answer_count'),  # 问题id，问题题目，问题回答数
                    question.get('follower_count'), question.get('comment_count'), question.get('created')
                    # 问题关注数，评论数，创建时间
                ]
            elif target_type == 'article':
                line = [
                    'article', item.get('id'), item.get('action_text'),  # 类型，总 id，关键词
                    target.get('id'), target.get('voteup_count'), target.get('comment_count'),  # 文章 id，文章点赞数，文章评论数
                    target.get('title'), target.get('visited_count'), target.get('created')  
                    # 文章题目（文章没有感谢数），文章观看数，文章创建时间 
                ]
            # elif target_type == 'question_ask':
            #     line = [
            #         'question_ask', item.get('id'), item.get('value')  # 类型，总 id，关键词
            #
            #     ]
            # elif target_type == 'zvideo':
            #     line = [
            #         'zvideo', item.get('id'), item.get('reason_text'),  # 类型，总 id，关键词
            #         target.get('id'), target.get('vote_count'), target.get('comment_count'),  # 视频 id，视频点赞数，视频评论数
            #         target.get('title'), target.get('followers_count'), target.get('created')  # 观看数 创建时间
            #     ]
            else:
                print('末能分类的项目：' + target_type)
                continue

            f_csv.writerow(line)  # 一次写入一行信息
            time.sleep(1)
# Out:
# 末能分类的项目：zvideo
# 末能分类的项目：zvideo
# 末能分类的项目：zvideo
# 末能分类的项目：zvideo
# 末能分类的项目：zvideo
# 末能分类的项目：zvideo
